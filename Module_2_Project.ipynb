# %%
import  pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('housing.csv')

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.describe()
# Out:
#         Rooms      Price  Distance  Postcode  Bedroom2  Bathroom     Car  \
# count 6847.00    6847.00   6847.00   6847.00   6847.00   6847.00 6819.00
# mean     2.98 1079246.22     10.12   3104.27      2.95      1.59    1.61
# std      0.97  673218.85      5.98     91.08      0.97      0.71    0.94
# min      1.00  131000.00      0.00   3000.00      0.00      1.00    0.00
# 25%      2.00  630000.00      6.10   3044.00      2.00      1.00    1.00
# 50%      3.00  892500.00      9.20   3083.00      3.00      1.00    2.00
# 75%      4.00 1336500.00     13.00   3148.00      4.00      2.00    2.00
# max      8.00 9000000.00     47.40   3977.00      9.00      8.00   10.00
#
#        Landsize  BuildingArea  YearBuilt  Propertycount
# count   6847.00       6847.00    6847.00        6847.00
# mean     463.28        142.96    1964.30        7432.04
# std      569.61         82.39      36.69        4348.51
# min        0.00          0.00    1830.00         389.00
# ...

# %%
df.head()
# Out:
#        Suburb          Address  Rooms   Type    Price               Method  \
# 0  Abbotsford  25 Bloomburg St      2  house  1035000        property sold
# 1  Abbotsford     5 Charles St      3  house  1465000  property sold prior
# 2  Abbotsford      55a Park St      4  house  1600000           vendor bid
# 3  Abbotsford     124 Yarra St      3  house  1876000        property sold
# 4  Abbotsford    98 Charles St      2  house  1636000        property sold
#
#   SellerG       Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  Biggin   4/2/2016      2.50      3067         2         1 0.00       156
# 1  Biggin   4/3/2017      2.50      3067         3         2 0.00       134
# 2  Nelson   4/6/2016      2.50      3067         3         1 2.00       120
# 3  Nelson   7/5/2016      2.50      3067         4         2 0.00       245
# 4  Nelson  8/10/2016      2.50      3067         2         1 2.00       256
#
# ...

# %%
sns.lmplot(data=df, x='Landsize', y='Price', hue='Type')
plt.show()

# %%
avg_price_year = df.groupby('YearBuilt')['Price'].mean().reset_index()
avg_price_year
# Out:
#      YearBuilt      Price
# 0      1830.00  855000.00
# 1      1850.00 1347000.00
# 2      1854.00 3310000.00
# 3      1856.00 2260000.00
# 4      1860.00 1980000.00
# ..         ...        ...
# 130    2014.00  951983.15
# 131    2015.00 1255708.33
# 132    2016.00 1529026.32
# 133    2017.00 1041406.31
# 134    2018.00 1310000.00
#
# [135 rows x 2 columns]

# %%
plt.plot(avg_price['YearBuilt'], avg_price['Price'])
plt.ticklabel_format(style='plain', axis='Y')
plt.show()

# %%
avg_price_reg = df.groupby('Regionname')['Price'].mean().reset_index()
avg_price_reg
# Out:
#                    Regionname      Price
# 0        Eastern Metropolitan 1118558.52
# 1            Eastern Victoria  681356.50
# 2       Northern Metropolitan  876597.05
# 3           Northern Victoria  569440.00
# 4  South-Eastern Metropolitan  939574.66
# 5       Southern Metropolitan 1408657.65
# 6        Western Metropolitan  873295.45
# 7            Western Victoria  408150.00

# %%
sns.barplot(x='Regionname', y='Price', data=avg_price_reg)
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(x='Price', data=df)
plt.show()

# %%
sns.boxplot(x='YearBuilt', y='Regionname', data=df)
plt.show()
